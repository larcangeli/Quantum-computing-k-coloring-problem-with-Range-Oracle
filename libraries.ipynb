# %%
# %pip install qiskit
# %pip install qiskit_aer
# %pip install networkx
# %pip install matplotlib
# %pip install alive_progress
# %pip install scipy
# %pip install numpy
# %pip install pylatexenc
# %pip install 'qiskit[visualization]'
# %pip install qiskit-ibm-runtime
# %pip install texlive
# %pip install qiskit-aer
# %pip install histogram
# Out:
# Requirement already satisfied: qiskit in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (5.4.0)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit) (0.13.0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.3->qiskit) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit_aer in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.16.4)
# Requirement already satisfied: qiskit>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit_aer) (1.4.1)
# Requirement already satisfied: numpy>=1.16.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit_aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit_aer) (1.11.4)
# Requirement already satisfied: psutil>=5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit_aer) (6.1.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (5.4.0)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit_aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit_aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit_aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit_aer) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (3.4.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.21 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: alive_progress in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (3.2.0)
# Requirement already satisfied: about-time==4.2.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from alive_progress) (4.2.1)
# Requirement already satisfied: grapheme==0.6.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from alive_progress) (0.6.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.11.4)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from scipy) (1.26.4)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylatexenc in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (2.10)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit[visualization] in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: rustworkx>=0.15.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (0.15.1)
# Requirement already satisfied: numpy<3,>=1.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (1.26.4)
# Requirement already satisfied: scipy>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (5.4.0)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (0.13.0)
# Requirement already satisfied: matplotlib>=3.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (3.8.2)
# Requirement already satisfied: pydot in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (3.0.4)
# Requirement already satisfied: Pillow>=4.2.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (11.0.0)
# Requirement already satisfied: pylatexenc>=1.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (2.10)
# Requirement already satisfied: seaborn>=0.9.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit[visualization]) (0.13.2)
# Requirement already satisfied: contourpy>=1.0.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from matplotlib>=3.3->qiskit[visualization]) (3.2.0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit[visualization]) (1.17.0)
# Requirement already satisfied: pandas>=1.2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from seaborn>=0.9.0->qiskit[visualization]) (2.1.4)
# Requirement already satisfied: pbr>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit[visualization]) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.3->qiskit[visualization]) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pandas>=1.2->seaborn>=0.9.0->qiskit[visualization]) (2024.2)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-ibm-runtime in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.35.0)
# Requirement already satisfied: requests>=2.19 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.32.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.13 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.26.4)
# Requirement already satisfied: urllib3>=1.21.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: websocket-client>=1.5.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.8.0)
# Requirement already satisfied: ibm-platform-services>=0.22.6 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (0.59.1)
# Requirement already satisfied: pydantic<2.10,>=2.5.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (2.9.2)
# Requirement already satisfied: qiskit>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-ibm-runtime) (1.4.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.22.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (3.22.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from pydantic<2.10,>=2.5.0->qiskit-ibm-runtime) (4.12.2)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (0.15.1)
# Requirement already satisfied: scipy>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (1.11.4)
# Requirement already satisfied: sympy>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (0.3.9)
# Requirement already satisfied: stevedore>=3.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (5.4.0)
# Requirement already satisfied: symengine<0.14,>=0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-ibm-runtime) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests>=2.19->qiskit-ibm-runtime) (2024.8.30)
# Requirement already satisfied: cryptography>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (44.0.0)
# Requirement already satisfied: pyspnego>=0.4.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.11.2)
# Requirement already satisfied: cffi>=1.12 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: PyJWT<3.0.0,>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.22.0->ibm-platform-services>=0.22.6->qiskit-ibm-runtime) (2.10.1)
# Requirement already satisfied: pbr>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-ibm-runtime) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: pycparser in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.22)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement texlive (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for texlive
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: qiskit-aer in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (0.16.4)
# Requirement already satisfied: qiskit>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-aer) (1.4.1)
# Requirement already satisfied: numpy>=1.16.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-aer) (1.26.4)
# Requirement already satisfied: scipy>=1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-aer) (1.11.4)
# Requirement already satisfied: psutil>=5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit-aer) (6.1.0)
# Requirement already satisfied: rustworkx>=0.15.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.15.1)
# Requirement already satisfied: sympy>=1.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (1.13.3)
# Requirement already satisfied: dill>=0.3 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.3.9)
# Requirement already satisfied: python-dateutil>=2.8.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: stevedore>=3.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (5.4.0)
# Requirement already satisfied: typing-extensions in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (4.12.2)
# Requirement already satisfied: symengine<0.14,>=0.11 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from qiskit>=1.1.0->qiskit-aer) (0.13.0)
# Requirement already satisfied: six>=1.5 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from python-dateutil>=2.8.0->qiskit>=1.1.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: pbr>=2.0.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from stevedore>=3.0.0->qiskit>=1.1.0->qiskit-aer) (6.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /system/conda/miniconda3/envs/cloudspace/lib/python3.10/site-packages (from sympy>=1.3->qiskit>=1.1.0->qiskit-aer) (1.3.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement histogram (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for histogram
# Note: you may need to restart the kernel to use updated packages.
